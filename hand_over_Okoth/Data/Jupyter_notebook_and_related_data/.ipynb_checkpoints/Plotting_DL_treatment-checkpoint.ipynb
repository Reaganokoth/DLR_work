# %%
# !pip3 install cartopy
# !pip3 install pycountry_covert
# #import pycountry_convert as pc
# !pip install import wget
# !pip install adjustText
# !pip3 install geopandas
# !pip3 install mapclassify
import cartopy.crs as ccrs
import re
import os
import requests
import matplotlib.pyplot as plt
from cartopy.feature import NaturalEarthFeature, LAND, COASTLINE
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
from bs4 import BeautifulSoup
from urllib.request import urlopen
import pandas as pd
import urllib
import geopandas as gpd
import geopandas as gpd
from zipfile import ZipFile
from shapely.geometry import Point
import matplotlib.pyplot as plt
import fiona
import adjustText as aT
import mapclassify
import numpy as np
import statistics as stats
from matplotlib import cm

# %%
# function to check for unique values in a list



def unique(list_):
    unique_list = []
    for item in list_:
        if item not in unique_list:
            unique_list.append(item)
    return unique_list

# %% [markdown]
# #### ***getISO3code***
# - This is a functionm to get the ISO-3 country codes.
# - The function is required for propper functioning of ***getGADMdata *** below.

# %%
# a function to get all the ISO3 coundtry codes from wikipedia

def getISO3code(country = None, table = None):
    
    link = "https://en.wikipedia.org/wiki/ISO_3166-1_alpha-3"
    session = urlopen(link)
    read_page = session.read().decode("utf-8")

    soup = BeautifulSoup(read_page, "html.parser")

    ISO_3 = soup.find_all("span", class_="monospaced")

    full_name = soup.find_all('a', title=True)


    ISO_3_code =[]

    names = []


    # get ISO codes

    for i in ISO_3:
        for child in i.descendants:
            ISO_3_code.append(child)
    
    #The data starts with Aruba nd ends with Zimbabwe
    for i in range(len(ISO_3_code)):

        if ISO_3_code[i] == "ABW":

            start_ISO = i

        elif ISO_3_code[i] == "ZWE":

            end_ISO = i       

    ISO3_complete = ISO_3_code[start_ISO:end_ISO+1]

   
    # Get the full names corresponding to each code
    
    for name in full_name:

        for child in name.descendants:

            names.append(child)


        
 # grab start and end of country names       


    for i in range(len(names)):
        if names[i] == "Aruba":
            start_name = i
        elif names[i] == "Zimbabwe":
            end_name =i
            
    fullNames = names[start_name:end_name+1]
    fullNames.remove('Province of China')
    
    data = pd.DataFrame(
    {'Country_name': fullNames,  'ISO3_Code':ISO3_complete}
    )
    
    exception_countries = ["Bolivia (Plurinational State of)", 
                            "Cocos (Keeling) Islands", 
                            "Falkland Islands (Malvinas)",
                            "Micronesia (Federated States of)",
                            "United Kingdom of Great Britain and Northern Ireland",
                            "Iran (Islamic Republic of)",
                            "Saint Martin (French part)",
                            "Korea, Republic of",
                            "Korea (Democratic People's Republic of)",
                            "Sint Maarten (Dutch part)",
                            "Venezuela (Bolivarian Republic of)",
                           ]
    common_name = ["Bolivia",
                   "Cocos Islands",
                   "Falkland Islands",
                   "Micronesia",
                   "United Kingdom",
                   "Iran",
                   "Saint Martin",
                   "South Korea",
                   "North Korea",
                   "Sint Maarten",
                   "Venezuela",]

    
    for rare_name, common_name in zip(exception_countries,common_name):
        data = data.replace(rare_name,common_name)
    
    if country:
        if table:
            return data[data.Country_name==country]
        else:
            return str(data[data.Country_name==country].iloc[0,1])
    else:
        return data

# %%
getISO3code("United Kingdom")
# Out:
# 'GBR'

# %% [markdown]
# #### ***getGADMdata*** is a function to rietrive administrative boundaries (upto level 3). The function is based on FAO GADM version 3.6 boundary data.
#
# **Available formats**
#
# - The ***"geopackage"*** format is the a very good general spatial data file format (for vector data). It is based on the SpatiaLite format, and can be read by software using GDAL/OGR, including R (with the 'sf' package), QGIS and ArcGIS you can specify this package like this (*file_format = 'gpkg'*).
#
# - A ***"shapefile"*** consist of at least four actual files (.shp, .shx, .dbf, .prj). This is an obsolete, but still commonly used format that can be directly used in a lot of software such as ArcGIS and DIVA-GIS, and many other programs(*file_format = 'shp'*).
#
# - "R sp" and "sf ***(.rds)*** and ***(.kmz)*** formats have not been implemented
#
# - To be implemented: the natural earth level 0 country boundaries for the entire world.

# %%
# retrieves the FAO GADM boundary data, level 3. the code is based on version 3.6 of the data

def getGADMdata(country = None, level= None, file_format = None):
    current_dir = os.getcwd()
    
    base_url = "https://biogeo.ucdavis.edu/data/gadm3.6/"
    
    if country:
        file_name = f'{country}_level3_Admin.zip'

        file_path = current_dir + "/" + file_name

        
        roi = getISO3code(f'{country}')
        link = base_url + str(file_format) + "/" +"gadm36_" + roi + "_" + str(file_format) +".zip"
        link = re.sub("None", "", link)
        
        print(f"downloading {country} Admin level {level} data from {link}")
        
    
            
        if file_format == "shp":
            
                if os.path.exists(file_path):
                    # Unzip the downloaded file and read it inton python

                    with ZipFile(file_path, 'r') as zipObj:
                        # Extract all the contents of zip file in current directory
                        zipObj.extractall()
                    
                    file_path = f'{current_dir}/gadm36_{roi}_{level}.{file_format}'
                    file_path = re.sub("None", "", file_path)
                    gpd_df = gpd.read_file(file_path)
                #return gpd_df[gpd_df.NAME_0 == country]
                else:
                    print(f"downloading data from {link}")
                
                    urllib.request.urlretrieve(link, file_path)
                    # Unzip the downloaded file and read it inton python
                    
                    with ZipFile(file_path, 'r') as zipObj:

                        # Extract all the contents of zip file in current directory
                        zipObj.extractall()
                    
                    file_path = f'{current_dir}/gadm36_{roi}_{level}.{file_format}'
                    file_path = re.sub("None", "", file_path)
                
                    gpd_df = gpd.read_file(file_path)
                    #gpd_df = gpd_df[gpd_df.NAME_0 == country]
        
        else: 
            if os.path.exists(file_path):
                file_path = f'{current_dir}/gadm36_{roi}.{file_format}'
                file_path = re.sub("None", "", file_path)
                gpd_df = gpd.read_file(file_path)
            else:
                print(f"downloading data from {link}")
                
                urllib.request.urlretrieve(link, file_path)
                file_path = f'{current_dir}/gadm36_{roi}.{file_format}'
                file_path = re.sub("None", "", file_path)
                gpd_df = gpd.read_file(file_path)
                
    return gpd_df

# %%
# Implementation 
oman = getGADMdata(country = "Saudi Arabia", file_format = "shp", level = "1")
oman.plot()
# Out:
# downloading Saudi Arabia Admin level 1 data from https://biogeo.ucdavis.edu/data/gadm3.6/shp/gadm36_SAU_shp.zip
# <AxesSubplot:>

# %% [markdown]
# # Importing and cleaning DL data

# %% [markdown]
# #### Computing the sum of treated areas for each country in (ha)
# - Read in the csv file with the row point data information.
# - Group the data by the country column and then compute the sum of the treated areas per country.

# %%
DL_data_2010_2021 = pd.read_csv("../DL_pdf_and_csv/2010_2021_DL_Treatment_Areas.csv")
point_data_2010_2021 = pd.read_csv("../DL_pdf_and_csv/2010_2021_DL_Treatment_points.csv")

#print(unique(DL_data_2010_2021.Country))

#2010_2021_DL_Treatment_Areas
def rename_country(csv_file,old_names, new_names):
    for old_name, new_name in zip(old_names,new_names):
        csv_file = csv_file.replace(old_name,new_name)
    return csv_file

#rename_country(csv_data_2019_2021, ['Islands', 'Arabia','Jamahiraya'], ['Cape Vade Islans','Saudi Arabia', 'Libya'])


#csv_data_2019_2021 = csv_data_2019_2021.replace("ARABIA","SAUDI ARABIA")


# group the data by the country colum and compute the sum
def group_by_Country(csv_file):
    
     # Capitalize the country names to match the naming in the global data
    csv_file["Country"] = csv_file["Country"].str.title()
    

    country_sum = csv_file.groupby(["Country"],as_index = False).sum()

   
    # drop the year information
    #country_sum["Country"] = country_sum["Country"].str.title()
    country_sum = country_sum.drop(["Year"],axis=1)

    #change the country name column to match the naming on the global dataset
    country_sum = country_sum.rename(columns = {'Country': "SOVEREIGNT"})
    return country_sum

# %%
#csv_data_2003_2005 = rename_country(csv_file = csv_data_2003_2005, old_names =['Islands', 'Arabia','Jamahiriya'], new_names =['Cape Vade Islands','Saudi Arabia', 'Libya'])
DL_data_2010_2021 = rename_country(csv_file = DL_data_2010_2021, old_names =['ARABIA', "Arabia"], new_names =['Saudi Arabia','Saudi Arabia'])
#unique(DL_data_2010_2021.Country)
DL_data_2010_2021
# Out:
#      Year Month       Country  T_area (ha)
# 0    2010   Apr  Saudi Arabia          673
# 1    2011   Apr       Algeria          440
# 2    2011   Apr         Egypt         2150
# 3    2011   Apr    Mauritania         8053
# 4    2011   Apr       Morocco          329
# ..    ...   ...           ...          ...
# 579  2020   Sep         Yemen         5828
# 580  2021   Sep      Ethiopia         3657
# 581  2021   Sep       Somalia         9972
# 582  2021   Sep         Sudan         1400
# 583  2021   Sep         Yemen          417
#
# [584 rows x 4 columns]

# %% [markdown]
# - Group the data by country and year, then compute the sum

# %%
#country_sum_2003_2005=group_by_Country(csv_data_2003_2005)
DL_country_sum_2010_2021=group_by_Country(DL_data_2010_2021)
DL_country_sum_2010_2021_year = DL_data_2010_2021.groupby(["Country", 'Year']).sum().reset_index()
#DL_country_sum_2010_2021_year = DL_country_sum_2010_2021_year.groupby(["Country"]).sum().reset_index()


# rename the coumtry to soverighn
#country_sum = country_sum.rename(columns = {'Country': "SOVEREIGNT"})
DL_country_sum_2010_2021_year = DL_country_sum_2010_2021_year.rename(columns = {'Country': "SOVEREIGNT"})
DL_country_sum_2010_2021_year
#unique(DL_country_sum_2010_2021_year.SOVEREIGNT)
# Out:
#       SOVEREIGNT  Year  T_area (ha)
# 0    Afghanistan  2020         2969
# 1        Algeria  2010         1208
# 2        Algeria  2011         1224
# 3        Algeria  2012        15501
# 4        Algeria  2013        17095
# ..           ...   ...          ...
# 135        Yemen  2014         3832
# 136        Yemen  2016          734
# 137        Yemen  2019        10837
# 138        Yemen  2020        47872
# 139        Yemen  2021          422
#
# [140 rows x 3 columns]

# %% [markdown]
# #### Join the csv data (the computed sum above) with the level 0 admin boundary polygons from natural earth
# - Do a spatial joint based on the country name column ('SOVEREIGNT') which is a common field in both datasets.

# %%
# load level 0 country plot and join it with the country_sum based on the SOVEREIGNT column
def join_treated_sum_with_adminboundary(country_sum):
    world_leve0_path = "ne_10m_admin_0_countries/ne_10m_admin_0_countries.shp"

    world_leve0 = gpd. read_file(world_leve0_path)
    #world_leve0.plot()

    world_level_0_country_sum_joined = world_leve0.join(country_sum.set_index('SOVEREIGNT'), on='SOVEREIGNT')
    
    return world_level_0_country_sum_joined

DL_by_country_sum_joined_2010_2021 = join_treated_sum_with_adminboundary(DL_country_sum_2010_2021)

# Filter the data to retain only countries with treated area data. 
# The write the overal totals to a folder in a local directory.


selected_DL_treatment_countries = DL_by_country_sum_joined_2010_2021[~DL_by_country_sum_joined_2010_2021['T_area (ha)'].isnull()]


if os.path.isdir("../DL_pdf_and_csv/overal_total_per_Country_shapefile"):
    print("directory exists")
    if os.path.isfile("../DL_pdf_and_csv/overal_total_per_Country_shapefile/overal_total_per_Country.shp"):
        print("overal_total_per_Country.shp already exists")
    else:
        selected_DL_treatment_countries.to_file("../DL_pdf_and_csv/overal_total_per_Country_shapefile/overal_total_per_Country.shp")
else:
    os.mkdir("../DL_pdf_and_csv/overal_total_per_Country_shapefile")
    selected_DL_treatment_countries.to_file("../DL_pdf_and_csv/overal_total_per_Country_shapefile/overal_total_per_Country.shp")






# if os.path.isfile("../DL_pdf_and_csv/overal_total_per_Country.shp"):
#     print(f"overal_total_per_Country.shp already exists")
# else:
#     DL_by_country_sum_joined_2010_2021.to_file("../DL_pdf_and_csv/overal_total_per_Country.shp")


DL_by_country_year_sum_joined_2010_2021 = join_treated_sum_with_adminboundary(DL_country_sum_2010_2021_year)
#world_level_0_country_sum_joined_2019_2021 = join_treated_sum_with_adminboundary(country_sum_2019_2021)
# Out:
# directory exists
# overal_total_per_Country.shp already exists

# %% [markdown]
# #### Make point_vector data from all the collected location information
# - In the csv_data that was previously loaded, there are the columns all_Nothing and all_Eastings which contain all the northings and Eastings available from FAO for each month and for each country.This information is stored as a list for each month (each month could have multiple locations mentioned). The goal of the code below is to extract each point and convert it into a proper geolocation (geopandas point dataframe) for visualization.
# - These points represents the locations where Desert Locusts (DL) have been spoted or treated (based on FAO monthly reports)

# %%
# Read the csv file and grab all the location data in the columns: all_Nothings and all_Easting and convert them
# to point vector data
#csv_data = pd.read_csv("../Decrypted/DL_Treatment_data_More_precise_Location2.csv")
#csv_data
def FAOreport_to_point(csv_file):
    lat = []
    lon = []
    countries = []
    months = []
    Years =[]

    for i in range(csv_file.shape[0]):
        year = csv_file.loc[i][0]
        month = csv_file.loc[i][1]
        country = csv_file.loc[i][2]


        all_North_monthly = csv_file.loc[i][3] 
        all_East_monthly = csv_file.loc[i][4] 



        points_lat = re.findall(r"[A-Z0-9]+",all_North_monthly) # just get the numbers and do not keep N/S this is becauswe all countries of interest are all in ther northern hemisphere
        points_lon = re.findall(r"[A-Z0-9]+",all_East_monthly) # keep the East/West information as some countries lie in the west of greenwitch. the coordinates will be assined to negative in that case


        for location_lat,location_lon  in zip(points_lat,points_lon):
            if country == "ARABIA" or country == "Arabia":
                countries.append("SAUDI ARABIA".title())
            else:
                countries.append(country)

            months.append(month)
            Years.append(year)

            #y_coord = float(location_lat[0:2] + "." + location_lat[2:4])
            #lat.append(y_coord)

            # check if the location in the west of GWM and assign -ve value else leave it as it is and only insert point.

            if location_lon[-1] == "W":
                x_coord = location_lon[0:-1]
                x_coord = float("-" + x_coord[0:2] + "." + x_coord[2:4])
                lon.append(x_coord)
            else:
                x_coord = location_lon[0:-1]
                x_coord = float(x_coord[0:2] + "." + x_coord[2:4])
                lon.append(x_coord)

            if location_lat[-1] == "S":
                x_coord1 = location_lat[0:-1]
                x_coord1 = float("-" + x_coord1[0:2] + "." + x_coord1[2:4])
                lat.append(x_coord1)
            else:
                x_coord1 = location_lat[0:-1]
                x_coord1 = float(x_coord1[0:2] + "." + x_coord1[2:4])
                lat.append(x_coord1)



    point_vector_data = pd.DataFrame(
       {'Year': Years, 'Month': months, 'Country': countries, 'Lat': lat, 'Lon': lon}
    )
    return point_vector_data
#point_vector_data

# %%
point_vector_data_2010_2021 = FAOreport_to_point(point_data_2010_2021)
#point_vector_data_2019_2021 = FAOreport_to_point(csv_data_2019_2021)

# %%
# Covert the above created point data into geopanda dataframe
def csv_to_gdf(point_data):
    geometry = [Point(xy) for xy in zip(point_data.Lon, point_data.Lat)]

    # drop the lon lat columns
    df = point_data.drop(['Lon', 'Lat'], axis=1)

    gdf = gpd.GeoDataFrame(df, crs="EPSG:4326", geometry=geometry)
    
    return gdf


gdf_2010_2021 = csv_to_gdf(point_vector_data_2010_2021)

gdf_2010_2021.plot()
# Out:
# <AxesSubplot:>

# %%
# Export the cleaned and processed DL point data top a local directory.

if os.path.isdir("../DL_pdf_and_csv/DL_treatment_point_data_shapefile"):
    print("directory exists")
    if os.path.isfile("../DL_pdf_and_csv/DL_treatment_point_data_shapefile/DL_treatment_points_2010_2021.shp"):
        print("DL_treatment_points_2010_2021.shp already exists")
    else:
        gpd.clip(gdf_2010_2021, selected_DL_treatment_countries).to_file("../DL_pdf_and_csv/DL_treatment_point_data_shapefile/DL_treatment_points_2010_2021.shp")
else:
    os.mkdir("../DL_pdf_and_csv/DL_treatment_point_data_shapefile")
    gpd.clip(gdf_2010_2021,selected_DL_treatment_countries).to_file("../DL_pdf_and_csv/DL_treatment_point_data_shapefile/DL_treatment_points_2010_2021.shp")


#selected_DL_treatment_countries
#gpd.clip(point, polygon)
# Out:
# directory exists
# DL_treatment_points_2010_2021.shp already exists

# %% [markdown]
# #### Distribution of total treated areas by country
# - Visualize the joined data

# %%
# Select countries with treated areas and grab their names. Plot their names at the centre of the polygon as text.

def treated_country_name(data):
    selected_rows = data[~data['T_area (ha)'].isnull()]


    selected_rows["center"] = selected_rows["geometry"].centroid
    
    #selected_rows["rep"] = selected_rows["geometry"].representative_point()

    selected_rows_points = selected_rows.copy()
    
    selected_rows_points.set_geometry("center", inplace = True)
    
    return (selected_rows_points)

# %%
def plot_teatment_sum_per_country (point, polygon, area, period):

    minx, miny, maxx, maxy = point.total_bounds


    ax = point.plot(figsize=(20,15),color='grey', zorder=2,legend=True)

    classi = mapclassify.UserDefined(
        polygon['T_area (ha)'], [0,100,1000,5000, 100000, 1000000, 2000000]
    )


    mapping = dict([(i,s) for i,s in enumerate(classi.get_legend_classes())])
    mapping

    def replace_legend_items(legend, mapping):
        for txt in legend.texts:
            for k,v in mapping.items():
                if txt.get_text() == str(k):
                    txt.set_text(v)



    #f, ax = plt.subplots(1, figsize=(16, 9))
    polygon.assign(cl=classi.yb).plot(column='cl', categorical=True, \
            k=10, cmap='PuRd',linewidth=0.1, ax=ax, \
            edgecolor='lightgrey', legend=True,
                              legend_kwds={'title': "Treated Area in Hacters",'loc': 'lower right'})
    #ax.set_axis_off()
    
    if period == "2003-2005":
        ax.set_xlim(minx-5, maxx +20)
        ax.set_ylim(miny, maxy+5)
    else:
        ax.set_xlim(minx-5, maxx +20)
        ax.set_ylim(miny-5, maxy-30)
    ax.set_title(f"Total Area Treated with Pesticide to Control Desert Locust during {period} Outbreak.")
    
    selected_rows_points = treated_country_name(polygon)

    texts_countryName = []
    texts_treatmentArea = []
    
    if area == True:
        field = "T_area (ha)"
    else:
        field = "SOVEREIGNT"

  

    for x, y, label in zip(selected_rows_points.geometry.x, selected_rows_points.geometry.y, selected_rows_points[field]):
        texts_treatmentArea.append(plt.text(x, y, label, fontsize = 8))

    aT.adjust_text(texts_treatmentArea, force_points=0.3, force_text=0.8, expand_points=(1,1), expand_text=(1,1), 
                   arrowprops=dict(arrowstyle="-", color='grey', lw=0.5))


    replace_legend_items(ax.get_legend(), mapping)
    plt.show()

# %%
plot_teatment_sum_per_country(point = gdf_2010_2021, polygon = DL_by_country_sum_joined_2010_2021,period = "2010-2021", area =True)

#plot_teatment_sum_per_country(point = gdf_2003_2005, polygon = world_level_0_country_sum_joined_2003_2005,period = "2003-2005", area =False)
# Out:
# <ipython-input-61-dea3b6d71ddb>:7: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   selected_rows["center"] = selected_rows["geometry"].centroid
# /Users/rragankonywa/opt/anaconda3/envs/GEE/lib/python3.8/site-packages/geopandas/geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)

# %% [markdown]
# #### Visualize How the point data is distributed in countries recording high treatments (the yelow regions in total treated reas by country figure).

# %%
# Make a function to plot specific country
# this code makes sense only for short periods of data. Not 10 years.

def countryPlot(point, country, period):
    
    polygon = getGADMdata(country = country, file_format = "shp", level = "1")
    polygon = polygon.set_crs(epsg=4326, inplace=True)
    
    
    polygon["center"] = polygon["geometry"].centroid
    #polygon["rep"] = polygon["geometry"].representative_point()
    polygon_with_points = polygon.copy()
    polygon_with_points.set_geometry("center", inplace = True)
    #polygon_with_points.set_geometry("rep", inplace = True)


#     world_level_0_country_sum_joined_points
#     ax = world_level_0_country_sum_joined.plot(figsize = (15, 12), color = "whitesmoke", edgecolor = "lightgrey", linewidth = 0.5)
    texts = []

    
    
    points = gpd.clip(point, polygon)
    points['Year'] = points['Year'].astype(str)
    
    points = points.set_crs (epsg=4326, inplace=True)
    fig, ax = plt.subplots(figsize=(20,15))
    
    
    
    polygon.plot(ax=ax, 
         facecolor='lightgrey',
         edgecolor='grey',
         #linewidth = 0.5,
         #color='k', 
         zorder=1,
         alpha=1,
         linewidth=1)
    
    key = unique(point.Year)
        
    viridis = cm.get_cmap('viridis', len(key))
    
    yearPalette = {}
   

    for i in key:
        yearPalette[str(i)] = viridis.colors[key.index(i)]
     
    
    for year, data in points.groupby('Year'):
        color = yearPalette[year]
        label = year
        data.plot(color=color,
                  ax=ax,
                  label=label,
                  markersize=100)

    
    ax.set_title(f"{period} Desert Locust Treatment Locations in {country}.")
    ax.legend(loc=("upper right"),
          fontsize=15,
          frameon=True,
          title="Legend")
    
    
    for x, y, label in zip(polygon_with_points.geometry.x, polygon_with_points.geometry.y, polygon_with_points["NAME_1"]):
        texts.append(plt.text(x, y, label, fontsize = 8))

    aT.adjust_text(texts, force_points=0.3, force_text=0.8, expand_points=(1,1), expand_text=(1,1), 
                   arrowprops=dict(arrowstyle="-", color='grey', lw=0.5))
    plt.show

# %%
countryPlot(point = gdf_2010_2021,country = "Ethiopia", period = "2010-2021")
# Out:
# downloading Ethiopia Admin level 1 data from https://biogeo.ucdavis.edu/data/gadm3.6/shp/gadm36_ETH_shp.zip
# <ipython-input-64-1290970faa68>:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   polygon["center"] = polygon["geometry"].centroid

# %%
#countryPlot("Saudi Arabia", period ="2019-2021")
countryPlot(point = gdf_2010_2021,country = "Saudi Arabia", period = "2010-2021")
#countryPlot(point = gdf_2003_2005,country = "Saudi Arabia", period = "2003-2005")
# Out:
# downloading Saudi Arabia Admin level 1 data from https://biogeo.ucdavis.edu/data/gadm3.6/shp/gadm36_SAU_shp.zip
# <ipython-input-64-1290970faa68>:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   polygon["center"] = polygon["geometry"].centroid

# %%
countryPlot(point = gdf_2010_2021,country = "India", period = "2010-2021")
#countryPlot(point = gdf_2003_2005,country = "India", period = "2003-2005")
# Out:
# downloading India Admin level 1 data from https://biogeo.ucdavis.edu/data/gadm3.6/shp/gadm36_IND_shp.zip
# <ipython-input-64-1290970faa68>:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   polygon["center"] = polygon["geometry"].centroid

# %%
countryPlot(point = gdf_2010_2021,country = "Pakistan", period = "2010-2021")
#countryPlot(point = gdf_2003_2005,country = "Pakistan", period = "2003-2005")
# Out:
# downloading Pakistan Admin level 1 data from https://biogeo.ucdavis.edu/data/gadm3.6/shp/gadm36_PAK_shp.zip
# <ipython-input-64-1290970faa68>:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   polygon["center"] = polygon["geometry"].centroid

# %% [markdown]
# # Plotting the other species overal total by country

# %%
other_species_csv_path = "../CIT_MDA_CCA_MLI_Cental_Asia_pdfs_and_csv/2010_2021_ACC_Treatment_Data.csv"

#Annual_Totals_shapefiles
other_species_csv = pd.read_csv(other_species_csv_path)
other_species_csv
# Out:
#      Year Month      Country  T_area (ha)
# 0    2020   Jul  Afghanistan       3746.0
# 1    2020   Jul      Armenia       1130.0
# 2    2020   Jul   Azerbaijan       8602.0
# 3    2020   Jul      Georgia      38081.0
# 4    2020   Jul   Kazakhstan      85400.0
# ..    ...   ...          ...          ...
# 344  2011   Jul      Armenia       1800.0
# 345  2011   Jul   Kyrgyzstan      61436.0
# 346  2011   Jul       Russia    1139600.0
# 347  2011   Jul   Tajikistan     137518.0
# 348  2011   Jul   Uzbekistan     448000.0
#
# [349 rows x 4 columns]

# %%
# group the data by country and get the sum per country
other_species_csv_country = other_species_csv.groupby(['Country']).sum().reset_index()
other_species_csv_country
# Out:
#         Country   Year  T_area (ha)
# 0   Afghanistan  66551    1575338.0
# 1       Armenia  30236      15658.0
# 2    Azerbaijan  70584     474795.5
# 3       Georgia  66511     378311.0
# 4    Kazakhstan  72598   15372686.0
# 5    Kyrgyzstan  86680    1022503.0
# 6        Russia  82658   11302704.0
# 7    Tajikistan  94743    1537521.0
# 8  Turkmenistan  34294     524173.0
# 9    Uzbekistan  98789    6150689.0

# %%
# Join the csv with the global country boundary
# rename the column and join the data
other_species_csv_country = other_species_csv_country.rename(columns = {'Country': "SOVEREIGNT"})
other_species_by_country_sum_joined_2010_2021 = join_treated_sum_with_adminboundary(other_species_csv_country)
other_species_by_country_sum_joined_2010_2021
# Out:
#           featurecla  scalerank  LABELRANK                    SOVEREIGNT  \
# 0    Admin-0 country          0          2                     Indonesia
# 1    Admin-0 country          0          3                      Malaysia
# 2    Admin-0 country          0          2                         Chile
# 3    Admin-0 country          0          3                       Bolivia
# 4    Admin-0 country          0          2                          Peru
# ..               ...        ...        ...                           ...
# 253  Admin-0 country          0          4                         China
# 254  Admin-0 country          6          5                     Australia
# 255  Admin-0 country          6          8  Bajo Nuevo Bank (Petrel Is.)
# 256  Admin-0 country          6          5               Serranilla Bank
# 257  Admin-0 country          6          6              Scarborough Reef
#
#     SOV_A3  ADM0_DIF  LEVEL               TYPE                         ADMIN  \
# 0      IDN         0      2  Sovereign country                     Indonesia
# 1      MYS         0      2  Sovereign country                      Malaysia
# 2      CHL         0      2  Sovereign country                         Chile
# 3      BOL         0      2  Sovereign country                       Bolivia
# 4      PER         0      2  Sovereign country                          Peru
# ..     ...       ...    ...                ...                           ...
# 253    CH1         1      2            Country                   Macao S.A.R
# 254    AU1         1      2         Dependency   Ashmore and Cartier Islands
# 255    BJN         0      2      Indeterminate  Bajo Nuevo Bank (Petrel Is.)
# 256    SER         0      2      Indeterminate               Serranilla Bank
# 257    SCR         0      2      Indeterminate              Scarborough Reef
#
#     ADM0_A3  ...     FCLASS_PL     FCLASS_GR     FCLASS_IT     FCLASS_NL  \
# 0       IDN  ...          None          None          None          None
# 1       MYS  ...          None          None          None          None
# 2       CHL  ...          None          None          None          None
# 3       BOL  ...          None          None          None          None
# 4       PER  ...          None          None          None          None
# ..      ...  ...           ...           ...           ...           ...
# 253     MAC  ...          None          None          None          None
# 254     ATC  ...          None          None          None          None
# 255     BJN  ...  Unrecognized  Unrecognized  Unrecognized  Unrecognized
# 256     SER  ...  Unrecognized  Unrecognized  Unrecognized  Unrecognized
# 257     SCR  ...          None          None          None          None
#
#         FCLASS_SE     FCLASS_BD     FCLASS_UA  \
# 0            None          None          None
# 1            None          None          None
# 2            None          None          None
# 3            None          None          None
# 4            None          None          None
# ..            ...           ...           ...
# 253          None          None          None
# 254          None          None          None
# 255  Unrecognized  Unrecognized  Unrecognized
# 256  Unrecognized  Unrecognized  Unrecognized
# 257          None          None          None
#
#                                               geometry Year T_area (ha)
# 0    MULTIPOLYGON (((117.70361 4.16341, 117.70361 4...  NaN         NaN
# 1    MULTIPOLYGON (((117.70361 4.16341, 117.69711 4...  NaN         NaN
# 2    MULTIPOLYGON (((-69.51009 -17.50659, -69.50611...  NaN         NaN
# 3    POLYGON ((-69.51009 -17.50659, -69.51009 -17.5...  NaN         NaN
# 4    MULTIPOLYGON (((-69.51009 -17.50659, -69.63832...  NaN         NaN
# ..                                                 ...  ...         ...
# 253  MULTIPOLYGON (((113.55860 22.16303, 113.56943 ...  NaN         NaN
# 254  POLYGON ((123.59702 -12.42832, 123.59775 -12.4...  NaN         NaN
# 255  POLYGON ((-79.98929 15.79495, -79.98782 15.796...  NaN         NaN
# 256  POLYGON ((-78.63707 15.86209, -78.64041 15.864...  NaN         NaN
# 257  POLYGON ((117.75389 15.15437, 117.75569 15.151...  NaN         NaN
#
# [258 rows x 164 columns]

# %%
# get the centropids of countries with treated area and return it as pointdata
def polygon_to_point(data):
    selected_rows = data[~data['T_area (ha)'].isnull()]
    
    
    center = selected_rows["geometry"].centroid
    #geopandas.GeoDataFrame
    
    #selected_rows["rep"] = selected_rows["geometry"].representative_point()

    #selected_rows_points = selected_rows.copy()
    
    #selected_rows_points.set_geometry("center", inplace = True)
    
    return (gpd.GeoDataFrame({'geometry':center}))

# %%
point_location_data = polygon_to_point(other_species_by_country_sum_joined_2010_2021)
point_location_data
# Out:
# <ipython-input-72-c2926e899ec1>:6: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   center = selected_rows["geometry"].centroid
#                       geometry
# 40   POINT (63.13991 41.75604)
# 41   POINT (67.29596 48.16065)
# 42   POINT (71.01583 38.52989)
# 47   POINT (96.62759 61.96685)
# 60   POINT (43.50753 42.16880)
# 63   POINT (47.54211 40.28912)
# 68   POINT (74.54167 41.46192)
# 69   POINT (44.93230 40.28813)
# 129  POINT (66.00845 33.83627)
# 142  POINT (59.37596 39.11593)
# 171  POINT (63.38390 45.97833)

# %%
# Plot other species overal total by country.

# %%
selected_countries = other_species_by_country_sum_joined_2010_2021[~other_species_by_country_sum_joined_2010_2021['T_area (ha)'].isnull()]

minx, miny, maxx, maxy = selected_countries.total_bounds


if os.path.isdir("../CIT_MDA_CCA_MLI_Cental_Asia_pdfs_and_csv/overal_total_per_Country_shapefile"):
    print("directory exists")
    if os.path.isfile("../CIT_MDA_CCA_MLI_Cental_Asia_pdfs_and_csv/overal_total_per_Country_shapefile/overal_total_per_Country.shp"):
        print("overal_total_per_Country.shp already exists")
    else:
        selected_countries.to_file("../CIT_MDA_CCA_MLI_Cental_Asia_pdfs_and_csv/overal_total_per_Country_shapefile/overal_total_per_Country.shp")
else:
    os.mkdir("../CIT_MDA_CCA_MLI_Cental_Asia_pdfs_and_csv/overal_total_per_Country_shapefile")
    selected_countries.to_file("../CIT_MDA_CCA_MLI_Cental_Asia_pdfs_and_csv/overal_total_per_Country_shapefile/overal_total_per_Country.shp")

    
    
# if os.path.isfile("../CIT_MDA_CCA_MLI_Cental_Asia_pdfs_and_csv/overal_total_per_Country.shp"):
#     print(f"{fileName} already exists")
# else:
#     selected_countries.to_file("../CIT_MDA_CCA_MLI_Cental_Asia_pdfs_and_csv/overal_total_per_Country.shp")


ax = fig, ax = plt.subplots(figsize=(20,15))
#selected_countries['Year'] = selected_countries['Year'].astype(str)

classi = mapclassify.UserDefined(
        selected_countries['T_area (ha)'], [0,20000, 200000, 500000, 1000000, 1500000, 3000000, 7000000, 12000000, 20000000]
    )

area = True
mapping = dict([(i,s) for i,s in enumerate(classi.get_legend_classes())])


def replace_legend_items(legend, mapping):
    for txt in legend.texts:
        for k,v in mapping.items():
            if txt.get_text() == str(k):
                txt.set_text(v)



#f, ax = plt.subplots(1, figsize=(16, 9))
selected_countries.assign(cl=classi.yb).plot(column='cl', categorical=True, \
        k=10, cmap='PuRd',linewidth=0.1, ax=ax, \
        edgecolor='lightgrey', legend=True,
                              legend_kwds={'title': "Treated Area in Hacters",'loc': 'lower right'})
    #ax.set_axis_off()
    

ax.set_xlim(minx+150)
mapping

selected_rows_points = treated_country_name(selected_countries)

texts_countryName = []
texts_treatmentArea = []
    
if area == True:
    field = "T_area (ha)"
else:
    field = "SOVEREIGNT"

for x, y, label in zip(selected_rows_points.geometry.x, selected_rows_points.geometry.y, selected_rows_points[field]):
    texts_treatmentArea.append(plt.text(x, y, label, fontsize = 8))

aT.adjust_text(texts_treatmentArea, force_points=0.3, force_text=0.8, expand_points=(1,1), expand_text=(1,1), 
            arrowprops=dict(arrowstyle="-", color='grey', lw=0.5))

ax.set_title(f"Total Area Treated with Pesticide to Control CCA locusts during 2010-2021 Period.")
replace_legend_items(ax.get_legend(), mapping)
plt.show()
#ax.set_ylim(miny-5, maxy-30)
# Out:
# directory exists
# overal_total_per_Country.shp already exists
# <ipython-input-61-dea3b6d71ddb>:7: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   selected_rows["center"] = selected_rows["geometry"].centroid

# %% [markdown]
# # Plot DL and other species overal total by year.

# %%
# group the data by country and year
other_species_csv_Year = other_species_csv.groupby(['Country', 'Year']).sum().reset_index()
other_species_csv_Year


other_species_csv_Year = other_species_csv_Year.rename(columns = {'Country': "SOVEREIGNT"})
other_species_country_sum_joined_2010_2021_Year = join_treated_sum_with_adminboundary(other_species_csv_Year)
other_species_country_sum_joined_2010_2021_Year
# Out:
#           featurecla  scalerank  LABELRANK                    SOVEREIGNT  \
# 0    Admin-0 country          0          2                     Indonesia
# 1    Admin-0 country          0          3                      Malaysia
# 2    Admin-0 country          0          2                         Chile
# 3    Admin-0 country          0          3                       Bolivia
# 4    Admin-0 country          0          2                          Peru
# ..               ...        ...        ...                           ...
# 253  Admin-0 country          0          4                         China
# 254  Admin-0 country          6          5                     Australia
# 255  Admin-0 country          6          8  Bajo Nuevo Bank (Petrel Is.)
# 256  Admin-0 country          6          5               Serranilla Bank
# 257  Admin-0 country          6          6              Scarborough Reef
#
#     SOV_A3  ADM0_DIF  LEVEL               TYPE                         ADMIN  \
# 0      IDN         0      2  Sovereign country                     Indonesia
# 1      MYS         0      2  Sovereign country                      Malaysia
# 2      CHL         0      2  Sovereign country                         Chile
# 3      BOL         0      2  Sovereign country                       Bolivia
# 4      PER         0      2  Sovereign country                          Peru
# ..     ...       ...    ...                ...                           ...
# 253    CH1         1      2            Country                   Macao S.A.R
# 254    AU1         1      2         Dependency   Ashmore and Cartier Islands
# 255    BJN         0      2      Indeterminate  Bajo Nuevo Bank (Petrel Is.)
# 256    SER         0      2      Indeterminate               Serranilla Bank
# 257    SCR         0      2      Indeterminate              Scarborough Reef
#
#     ADM0_A3  ...     FCLASS_PL     FCLASS_GR     FCLASS_IT     FCLASS_NL  \
# 0       IDN  ...          None          None          None          None
# 1       MYS  ...          None          None          None          None
# 2       CHL  ...          None          None          None          None
# 3       BOL  ...          None          None          None          None
# 4       PER  ...          None          None          None          None
# ..      ...  ...           ...           ...           ...           ...
# 253     MAC  ...          None          None          None          None
# 254     ATC  ...          None          None          None          None
# 255     BJN  ...  Unrecognized  Unrecognized  Unrecognized  Unrecognized
# 256     SER  ...  Unrecognized  Unrecognized  Unrecognized  Unrecognized
# 257     SCR  ...          None          None          None          None
#
#         FCLASS_SE     FCLASS_BD     FCLASS_UA  \
# 0            None          None          None
# 1            None          None          None
# 2            None          None          None
# 3            None          None          None
# 4            None          None          None
# ..            ...           ...           ...
# 253          None          None          None
# 254          None          None          None
# 255  Unrecognized  Unrecognized  Unrecognized
# 256  Unrecognized  Unrecognized  Unrecognized
# 257          None          None          None
#
#                                               geometry Year T_area (ha)
# 0    MULTIPOLYGON (((117.70361 4.16341, 117.70361 4...  NaN         NaN
# 1    MULTIPOLYGON (((117.70361 4.16341, 117.69711 4...  NaN         NaN
# 2    MULTIPOLYGON (((-69.51009 -17.50659, -69.50611...  NaN         NaN
# 3    POLYGON ((-69.51009 -17.50659, -69.51009 -17.5...  NaN         NaN
# 4    MULTIPOLYGON (((-69.51009 -17.50659, -69.63832...  NaN         NaN
# ..                                                 ...  ...         ...
# 253  MULTIPOLYGON (((113.55860 22.16303, 113.56943 ...  NaN         NaN
# 254  POLYGON ((123.59702 -12.42832, 123.59775 -12.4...  NaN         NaN
# 255  POLYGON ((-79.98929 15.79495, -79.98782 15.796...  NaN         NaN
# 256  POLYGON ((-78.63707 15.86209, -78.64041 15.864...  NaN         NaN
# 257  POLYGON ((117.75389 15.15437, 117.75569 15.151...  NaN         NaN
#
# [368 rows x 164 columns]

# %%
# available_years = unique(other_species_csv.Year)

# for year in available_years:

#     Year = year
#     fileName = f"{Year}_treated_areas.shp"


#     selected_countries = world_level_0_country_sum_joined_2010_2021_Year[~world_level_0_country_sum_joined_2010_2021_Year['T_area (ha)'].isnull()]
#     selected_countries = selected_countries[selected_countries["Year"]==Year]
    
#     if os.path.isfile(f"../CIT_MDA_CCA_MLI_Cental_Asia_pdfs_and_csv/Annual_Totals_shapefiles/{fileName}"):
#         print(f"{fileName} already exists")
#     else:
#         selected_countries.to_file(f"../CIT_MDA_CCA_MLI_Cental_Asia_pdfs_and_csv/Annual_Totals_shapefiles/{Year}_treated_areas.shp")
    

#     minx, miny, maxx, maxy = selected_countries.total_bounds


#     ax = fig, ax = plt.subplots(figsize=(20,15))
#     #selected_countries['Year'] = selected_countries['Year'].astype(str)

#     classi = mapclassify.UserDefined(
#             selected_countries['T_area (ha)'], [0,100000,200000,500000, 1000000, 2000000, 3000000, 4000000, 5000000,6000000,7000000,8000000]
#         )

#     area = "area"
#     mapping = dict([(i,s) for i,s in enumerate(classi.get_legend_classes())])


#     def replace_legend_items(legend, mapping):
#         for txt in legend.texts:
#             for k,v in mapping.items():
#                 if txt.get_text() == str(k):
#                     txt.set_text(v)



#     #f, ax = plt.subplots(1, figsize=(16, 9))
#     selected_countries.assign(cl=classi.yb).plot(column='cl', categorical=True, \
#             k=10, cmap='PuRd',linewidth=0.1, ax=ax, \
#             edgecolor='lightgrey', legend=True,
#                                   legend_kwds={'title': "Treated Area in Hacters",'loc': 'lower right'})
#         #ax.set_axis_off()


#     ax.set_xlim(minx+150)
#     mapping

#     selected_rows_points = treated_country_name(selected_countries)

#     texts_countryName = []
#     texts_treatmentArea = []

#     if area == "area":
#         field = "T_area (ha)"
#     elif area == "country":
#         field = "SOVEREIGNT"
#     else:
#         field = "Year"

#     for x, y, label in zip(selected_rows_points.geometry.x, selected_rows_points.geometry.y, selected_rows_points[field]):
#         texts_treatmentArea.append(plt.text(x, y, label, fontsize = 8))

#     aT.adjust_text(texts_treatmentArea, force_points=0.3, force_text=0.8, expand_points=(1,1), expand_text=(1,1), 
#                 arrowprops=dict(arrowstyle="-", color='grey', lw=0.5))

#     ax.set_title(f"Total Area Treated with Pesticide to Control CCA locusts during {Year} Period.")
#     replace_legend_items(ax.get_legend(), mapping)
#     index = available_years.index(Year)
#     if index == len(available_years):
#         plt.show()
# #ax.set_ylim(miny-5, maxy-30)

# %%
def annual_total_plots(shape_file, path,show_plot):



    available_years = unique(other_species_csv.Year)

    for year in available_years:

        Year = year
        fileName = f"{Year}_treated_areas.shp"


        selected_countries = shape_file[~shape_file['T_area (ha)'].isnull()]
        selected_countries = selected_countries[selected_countries["Year"]==Year]
        
        if os.path.isdir(f'{path}{Year}'):
            print("dierectory exists")
            if os.path.isfile(f"{path}{Year}/{fileName}"):
                print(f"{fileName} already exists")
            else:
                selected_countries.to_file(f"{path}{fileName}")
        else:
            os.mkdir(f"{path}{Year}")
            selected_countries.to_file(f"{path}{Year}/{fileName}")
            

       


        minx, miny, maxx, maxy = selected_countries.total_bounds


        ax = fig, ax = plt.subplots(figsize=(20,15))
        #selected_countries['Year'] = selected_countries['Year'].astype(str)

        classi = mapclassify.UserDefined(
                selected_countries['T_area (ha)'], [0,100000,200000,500000, 1000000, 2000000, 3000000, 4000000, 5000000,6000000,7000000,8000000]
            )

        area = "area"
        mapping = dict([(i,s) for i,s in enumerate(classi.get_legend_classes())])


        def replace_legend_items(legend, mapping):
            for txt in legend.texts:
                for k,v in mapping.items():
                    if txt.get_text() == str(k):
                        txt.set_text(v)



        #f, ax = plt.subplots(1, figsize=(16, 9))
        selected_countries.assign(cl=classi.yb).plot(column='cl', categorical=True, \
                k=10, cmap='PuRd',linewidth=0.1, ax=ax, \
                edgecolor='lightgrey', legend=True,
                                      legend_kwds={'title': "Treated Area in Hacters",'loc': 'lower right'})
            #ax.set_axis_off()


        ax.set_xlim(minx+150)
        mapping

        selected_rows_points = treated_country_name(selected_countries)

        texts_countryName = []
        texts_treatmentArea = []

        if area == "area":
            field = "T_area (ha)"
        elif area == "country":
            field = "SOVEREIGNT"
        else:
            field = "Year"

        for x, y, label in zip(selected_rows_points.geometry.x, selected_rows_points.geometry.y, selected_rows_points[field]):
            texts_treatmentArea.append(plt.text(x, y, label, fontsize = 8))

        aT.adjust_text(texts_treatmentArea, force_points=0.3, force_text=0.8, expand_points=(1,1), expand_text=(1,1), 
                    arrowprops=dict(arrowstyle="-", color='grey', lw=0.5))

        ax.set_title(f"Total Area Treated with Pesticide to Control CCA locusts during {Year} Period.")
        replace_legend_items(ax.get_legend(), mapping)
        index = available_years.index(Year)
        if show_plot == True:
            plt.show()
        #ax.set_ylim(miny-5, maxy-30)

# %%
# the function works well. Test it on the DL data.

annual_total_plots(shape_file=other_species_country_sum_joined_2010_2021_Year, path="../CIT_MDA_CCA_MLI_Cental_Asia_pdfs_and_csv/Annual_Totals_shapefiles/",show_plot=False)

#world_level_0_country_sum_joined_2010_2021_Year
# Out:
# dierectory exists
# 2020_treated_areas.shp already exists
# <ipython-input-61-dea3b6d71ddb>:7: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   selected_rows["center"] = selected_rows["geometry"].centroid
# dierectory exists
# 2017_treated_areas.shp already exists
# <ipython-input-61-dea3b6d71ddb>:7: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   selected_rows["center"] = selected_rows["geometry"].centroid
# dierectory exists
# 2021_treated_areas.shp already exists
# <ipython-input-61-dea3b6d71ddb>:7: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   selected_rows["center"] = selected_rows["geometry"].centroid
# dierectory exists
# 2014_treated_areas.shp already exists
# <ipython-input-61-dea3b6d71ddb>:7: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   selected_rows["center"] = selected_rows["geometry"].centroid
# dierectory exists
# 2015_treated_areas.shp already exists
# <ipython-input-61-dea3b6d71ddb>:7: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   selected_rows["center"] = selected_rows["geometry"].centroid
# dierectory exists
# 2018_treated_areas.shp already exists
# <ipython-input-61-dea3b6d71ddb>:7: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   selected_rows["center"] = selected_rows["geometry"].centroid
# dierectory exists
# 2019_treated_areas.shp already exists
# <ipython-input-61-dea3b6d71ddb>:7: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   selected_rows["center"] = selected_rows["geometry"].centroid
# dierectory exists
# 2010_treated_areas.shp already exists
# <ipython-input-61-dea3b6d71ddb>:7: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   selected_rows["center"] = selected_rows["geometry"].centroid
# dierectory exists
# 2013_treated_areas.shp already exists
# <ipython-input-61-dea3b6d71ddb>:7: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   selected_rows["center"] = selected_rows["geometry"].centroid
# dierectory exists
# 2012_treated_areas.shp already exists
# <ipython-input-61-dea3b6d71ddb>:7: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   selected_rows["center"] = selected_rows["geometry"].centroid
# dierectory exists
# 2011_treated_areas.shp already exists
# <ipython-input-61-dea3b6d71ddb>:7: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   selected_rows["center"] = selected_rows["geometry"].centroid
# dierectory exists
# 2016_treated_areas.shp already exists
# <ipython-input-61-dea3b6d71ddb>:7: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   selected_rows["center"] = selected_rows["geometry"].centroid

# %%
annual_total_plots(shape_file=DL_by_country_year_sum_joined_2010_2021, path="../DL_pdf_and_csv/Annual_Totals_shapefiles/",show_plot=False)


DL_country_sum_2010_2021_year
# Out:
# dierectory exists
# 2020_treated_areas.shp already exists
# <ipython-input-61-dea3b6d71ddb>:7: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   selected_rows["center"] = selected_rows["geometry"].centroid
# dierectory exists
# 2017_treated_areas.shp already exists
# <ipython-input-61-dea3b6d71ddb>:7: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   selected_rows["center"] = selected_rows["geometry"].centroid
# dierectory exists
# 2021_treated_areas.shp already exists
# <ipython-input-61-dea3b6d71ddb>:7: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   selected_rows["center"] = selected_rows["geometry"].centroid
# dierectory exists
# 2014_treated_areas.shp already exists
# <ipython-input-61-dea3b6d71ddb>:7: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   selected_rows["center"] = selected_rows["geometry"].centroid
# dierectory exists
# 2015_treated_areas.shp already exists
# <ipython-input-61-dea3b6d71ddb>:7: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   selected_rows["center"] = selected_rows["geometry"].centroid
# dierectory exists
# 2018_treated_areas.shp already exists
# <ipython-input-61-dea3b6d71ddb>:7: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   selected_rows["center"] = selected_rows["geometry"].centroid
# dierectory exists
# 2019_treated_areas.shp already exists
# <ipython-input-61-dea3b6d71ddb>:7: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   selected_rows["center"] = selected_rows["geometry"].centroid
# dierectory exists
# 2010_treated_areas.shp already exists
# <ipython-input-61-dea3b6d71ddb>:7: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   selected_rows["center"] = selected_rows["geometry"].centroid
# dierectory exists
# 2013_treated_areas.shp already exists
# <ipython-input-61-dea3b6d71ddb>:7: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   selected_rows["center"] = selected_rows["geometry"].centroid
# dierectory exists
# 2012_treated_areas.shp already exists
# <ipython-input-61-dea3b6d71ddb>:7: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   selected_rows["center"] = selected_rows["geometry"].centroid
# dierectory exists
# 2011_treated_areas.shp already exists
# <ipython-input-61-dea3b6d71ddb>:7: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   selected_rows["center"] = selected_rows["geometry"].centroid
# dierectory exists
# 2016_treated_areas.shp already exists
# <ipython-input-61-dea3b6d71ddb>:7: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   selected_rows["center"] = selected_rows["geometry"].centroid
#       SOVEREIGNT  Year  T_area (ha)
# 0    Afghanistan  2020         2969
# 1        Algeria  2010         1208
# 2        Algeria  2011         1224
# 3        Algeria  2012        15501
# 4        Algeria  2013        17095
# ..           ...   ...          ...
# 135        Yemen  2014         3832
# 136        Yemen  2016          734
# 137        Yemen  2019        10837
# 138        Yemen  2020        47872
# 139        Yemen  2021          422
#
# [140 rows x 3 columns]
